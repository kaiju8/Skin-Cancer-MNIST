# %%
import os, itertools

import numpy as np 
import pandas as pd 
from pandas import DataFrame

import matplotlib.pyplot as plt

import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from torch.utils.data import DataLoader,Dataset,WeightedRandomSampler

import torchvision
import torchvision.transforms as T
from torchvision import models 

from sklearn.metrics import confusion_matrix
from sklearn.metrics import classification_report

from skimage import io

# %%
torch.manual_seed(1234)

# %% [markdown]
# ### Extraction of Images from directories and Labels from metadata.csv

# %%
metadata_csv = '/kaggle/input/skin-cancer-mnist-ham10000/HAM10000_metadata.csv'
img_dir_1 = '/kaggle/input/skin-cancer-mnist-ham10000/HAM10000_images_part_1'
img_dir_2 = '/kaggle/input/skin-cancer-mnist-ham10000/HAM10000_images_part_2'

# %% [markdown]
# Othe csv files do not contain new that and are from [this](https://www.kaggle.com/code/kmader/dermatology-mnist-loading-and-processing/notebook) <br>

# %%
metadata = pd.read_csv(metadata_csv)
metadata
# Out:
#          lesion_id      image_id     dx dx_type   age     sex localization
# 0      HAM_0000118  ISIC_0027419    bkl   histo  80.0    male        scalp
# 1      HAM_0000118  ISIC_0025030    bkl   histo  80.0    male        scalp
# 2      HAM_0002730  ISIC_0026769    bkl   histo  80.0    male        scalp
# 3      HAM_0002730  ISIC_0025661    bkl   histo  80.0    male        scalp
# 4      HAM_0001466  ISIC_0031633    bkl   histo  75.0    male          ear
# ...            ...           ...    ...     ...   ...     ...          ...
# 10010  HAM_0002867  ISIC_0033084  akiec   histo  40.0    male      abdomen
# 10011  HAM_0002867  ISIC_0033550  akiec   histo  40.0    male      abdomen
# 10012  HAM_0002867  ISIC_0033536  akiec   histo  40.0    male      abdomen
# 10013  HAM_0000239  ISIC_0032854  akiec   histo  80.0    male         face
# 10014  HAM_0003521  ISIC_0032258    mel   histo  70.0  female         back
#
# [10015 rows x 7 columns]

# %% [markdown]
# Multiple Images for each lesion exist, to avoid inflating validation accuracy we only chose one image per lesion

# %%
metadata = metadata.drop_duplicates(subset=['lesion_id'])
metadata = metadata.sample(frac = 1)

metadata.index = np.arange(0, len(metadata))
metadata
# Out:
#         lesion_id      image_id     dx    dx_type   age     sex  \
# 0     HAM_0003885  ISIC_0027560    mel      histo  25.0  female
# 1     HAM_0001981  ISIC_0024342     nv  follow_up  40.0    male
# 2     HAM_0001257  ISIC_0024614     nv  follow_up  35.0  female
# 3     HAM_0007026  ISIC_0027085     nv  follow_up  35.0    male
# 4     HAM_0006966  ISIC_0028614     nv  follow_up  30.0  female
# ...           ...           ...    ...        ...   ...     ...
# 7465  HAM_0006787  ISIC_0026471     df  consensus  60.0    male
# 7466  HAM_0007357  ISIC_0031265     nv  follow_up  40.0  female
# 7467  HAM_0001178  ISIC_0031570  akiec      histo  70.0  female
# 7468  HAM_0004218  ISIC_0028256     nv  follow_up  60.0    male
# 7469  HAM_0006025  ISIC_0031285     nv      histo  70.0  female
#
#          localization
# 0                face
# 1     lower extremity
# 2             abdomen
# 3               trunk
# 4               trunk
# ...               ...
# 7465  lower extremity
# 7466            trunk
# 7467             back
# 7468            trunk
# 7469             foot
#
# [7470 rows x 7 columns]

# %%
train_csv = metadata.iloc[1000:,:]
train_csv.index = np.arange(0, len(train_csv))

test_csv = metadata.iloc[:1000,:]

# %%
class CustomDataset(Dataset):# For Images in a root_dir_1(2) and labels in csv
    
    def __init__(self, metadata_pd, root_dir_1, root_dir_2, transform=None):
        self.metadata = metadata_pd
        self.root_dir_1 = root_dir_1
        self.root_dir_2 = root_dir_2
        self.transform = transform
        self.label_dict = {
            'nv': 0, 
            'mel': 1, 
            'bkl': 2,
            'bcc': 3,
            'akiec': 4,
            'vasc': 5,
            'df': 6
        } 
        
    def __len__(self):
        return len(self.metadata)
    
    def __getitem__(self, index):
        
        img_path = os.path.join(self.root_dir_1, self.metadata.iloc[index, 1]+'.jpg')
        
        if os.path.exists(img_path):
            image = io.imread(img_path)
            label = self.label_dict[self.metadata.iloc[index, 2]]
            
            if self.transform:
                image = self.transform(image)
            
            return(image, label)
        
        img_path = os.path.join(self.root_dir_2, self.metadata.iloc[index, 1]+'.jpg')
        
        if os.path.exists(img_path):
            image = io.imread(img_path)
            label = self.label_dict[self.metadata.iloc[index, 2]]
            
            if self.transform:
                image = self.transform(image)
            
            return(image, label)
        else:
            return None

# %%
train_transformation = T.Compose([
    T.ToTensor(),
    T.Resize((224, 280), antialias=True),
    T.CenterCrop((224, 224)),
    T.RandomHorizontalFlip(p=0.5),
    T.RandomApply(transforms=[T.RandomRotation(degrees=(-180, 180))], p=0.99),
    T.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])
])
test_transformation = T.Compose([
    T.ToTensor(),
    T.Resize((224, 280), antialias=True),
    T.CenterCrop((224, 224)),
    T.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])
    ])

train_data = CustomDataset(metadata_pd = train_csv, root_dir_1=img_dir_1, root_dir_2=img_dir_2, transform=train_transformation)
test_data = CustomDataset(metadata_pd = test_csv, root_dir_1=img_dir_1, root_dir_2=img_dir_2, transform=test_transformation)


val_data, test_data = torch.utils.data.random_split(test_data, [0.5,0.5])

# %% [markdown]
# # Visualization

# %%
def display_data(dataset):
    figure = plt.figure(figsize=(8, 8))
    cols, rows = 3, 3

    for i in range(1, cols * rows + 1):
        sample_idx = torch.randint(len(dataset), size=(1,)).item()
        img, label = dataset[sample_idx]
        figure.add_subplot(rows, cols, i)
        plt.title(label)
        plt.axis("off")
        plt.imshow(img.permute(1, 2, 0))
    plt.show()

display_data(test_data)

# %% [markdown]
# # DataLoaders and Weighted Sampling

# %% [markdown]
# ### Weighted Sampling

# %%
fig, ax1 = plt.subplots(1, 1, figsize = (5, 2))
metadata['dx'].value_counts().plot(kind='bar', ax=ax1)

metadata['dx'].value_counts()
# Out:
# nv       5403
# bkl       727
# mel       614
# bcc       327
# akiec     228
# vasc       98
# df         73
# Name: dx, dtype: int64

# %% [markdown]
# This Dataset has Imbalanced Distribution of labels, thus Oversampling is used to create the DataLoader

# %%
array = metadata['dx'].value_counts()

class_weights = []
for i in range(len(array)):
    class_weights.append(1/array.iloc[i])

train_sample_weights = [0]*len(train_data)

for idx, (data, label) in enumerate(train_data):
    train_sample_weights[idx] = class_weights[label]

# %% [markdown]
# ### Creating dataloaders for each dataset

# %%
batch_size = 64

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# %%
train_sampler = WeightedRandomSampler(train_sample_weights, num_samples=len(train_data), replacement=True)

train_loader = DataLoader(train_data, batch_size=batch_size, sampler=train_sampler)
val_loader = DataLoader(val_data, batch_size=batch_size)
test_loader = DataLoader(test_data, batch_size=batch_size)

# %% [markdown]
# # Model Setup

# %%
target_labels = ['Melanocytic nevi',
                 'Melanoma',
                 'Benign keratosis like lesions ',
                 'Basal cell carcinoma',
                 'Actinic keratoses',
                 'Vascular lesions',
                 'Dermatofibroma']

# %%
input_size = 224
sequence_length = 224*3
num_layers = 16
hidden_size = 256

learning_rate = 0.001
num_epochs = 40

# %%
class LSTM(nn.Module):
    def __init__(self, input_size, hidden_size, num_layers, num_classes):
        super(LSTM,self).__init__()
        self.hidden_size = hidden_size
        self.num_layers = num_layers
        self.lstm = nn.LSTM(input_size, hidden_size, num_layers, batch_first=True)#replacable with nn.GRU
        self.fc = nn.Linear(sequence_length*hidden_size, num_classes)
    
    def forward(self, x):
        h0 = torch.zeros(self.num_layers, x.size(0), self.hidden_size).to(device)
        c0 = torch.zeros(self.num_layers, x.size(0), self.hidden_size).to(device)#new addition

        # Forward prop
        out, _ = self.lstm(x, (h0,c0))# new
        out = out.reshape(out.shape[0], -1)
        out = self.fc(out)
        return out

# %%
model = LSTM(input_size, hidden_size, num_layers, len(target_labels))

criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(model.parameters(), lr=learning_rate)
     
model = model.to(device)

# %% [markdown]
# ### Some required functions

# %%
def save_checkpoint(state, filename="my_checkpoint.pth.tar"):
    print("=> Saving checkpoint")
    torch.save(state, filename)

def load_checkpoint(checkpoint):
    print("=> Loading checkpoint")
    model.load_state_dict(checkpoint['state_dict'])
    optimizer.load_state_dict(checkpoint['optimizer'])
    
def get_accuracy(y_pred, y_true):
    _, predicted = torch.max(y_pred, 1)
    total = y_true.size(0)
    correct = (predicted == y_true).sum().item()
    accuracy = correct / total
    return accuracy

def plot_confusion_matrix(cm, classes,normalize=False, title='Confusion matrix with DenseNet121', cmap=plt.cm.Blues):
    """
    This function prints and plots the confusion matrix.
    Normalization can be applied by setting `normalize=True`.
    """
    plt.figure(figsize=(6,6))
    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title)
    plt.colorbar()
    tick_marks = np.arange(len(classes))
    plt.xticks(tick_marks, classes, rotation=45)
    plt.yticks(tick_marks, classes)

    if normalize:
        cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]

    thresh = cm.max() / 2.
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        plt.text(j, i, cm[i, j],
                 horizontalalignment="center",
                 color="white" if cm[i, j] > thresh else "black")

    plt.tight_layout()
    plt.ylabel('True label')
    plt.xlabel('Predicted label')
    plt.savefig('confusion_matrix.png' , format="png", bbox_inches='tight')
    plt.show()

# %% [markdown]
# # Training

# %%
load_model = False

if load_model:
    load_checkpoint(torch.load('my_checkpoint.pth.tar'))

# %%
for epoch in range(num_epochs):
    
    train_loss = 0.0
    train_acc = 0.0
    
    model.train()
    
    if epoch%3==0:
        checkpoint = {'state_dict' : model.state_dict(), 'optimizer' : optimizer.state_dict()}
        save_checkpoint(checkpoint)
        
    for data, labels in train_loader:
        
        data = data.to(device)
        labels = labels.to(device)
        
        data = data.reshape(data.shape[0], data.shape[1]*data.shape[2], data.shape[3])
        
        optimizer.zero_grad()
        
        # Forward pass
        outputs = model(data)
        loss = criterion(outputs, labels)
        
        # Backward pass and optimization
        loss.backward()
        optimizer.step()
        
        train_loss += loss.item() * data.size(0)
        train_acc += get_accuracy(outputs, labels) * data.size(0)
        
    train_acc = train_acc / len(train_data)
    train_loss = train_loss / len(train_data)
    
    val_loss = 0.0
    val_acc = 0.0
    
    model.eval()
        
    for data, labels in val_loader:
        
        data = data.to(device)
        labels = labels.to(device)
        
        data = data.reshape(data.shape[0], data.shape[1]*data.shape[2], data.shape[3])
        
        optimizer.zero_grad()
        
        #Foward pass only
        outputs = model(data)
        loss = criterion(outputs, labels)
        
        val_loss += loss.item() * data.size(0)
        val_acc += get_accuracy(outputs, labels) * data.size(0)
    
    
    # Calculate average loss and accuracy for the epoch
    val_loss = val_loss / len(val_data)
    val_acc = val_acc / len(val_data)
    
    # Print training losses and accuracies for the epoch
    print(f"Epoch {epoch+1}/{num_epochs}, Training Loss: {train_loss:.4f}, Training Accuracy: {train_acc:.4f}, Validation Loss: {val_loss:.4f}, Validation Accuracy: {val_acc:.4f}")
# Out:
# => Saving checkpoint
# Epoch 1/40, Training Loss: 2.0218, Training Accuracy: 0.1566, Validation Loss: 2.0727, Validation Accuracy: 0.0980
# Epoch 2/40, Training Loss: 1.9520, Training Accuracy: 0.1618, Validation Loss: 2.0691, Validation Accuracy: 0.0060
# Epoch 3/40, Training Loss: 1.9530, Training Accuracy: 0.1461, Validation Loss: 2.1049, Validation Accuracy: 0.0100
# => Saving checkpoint
# Epoch 4/40, Training Loss: 1.9470, Training Accuracy: 0.1640, Validation Loss: 1.9898, Validation Accuracy: 0.0060
# Epoch 5/40, Training Loss: 1.9489, Training Accuracy: 0.1533, Validation Loss: 1.9584, Validation Accuracy: 0.0980
# Epoch 6/40, Training Loss: 1.9505, Training Accuracy: 0.1546, Validation Loss: 1.9968, Validation Accuracy: 0.0980
# => Saving checkpoint
# Epoch 7/40, Training Loss: 1.9461, Training Accuracy: 0.1675, Validation Loss: 1.8582, Validation Accuracy: 0.0060
# Epoch 8/40, Training Loss: 1.9467, Training Accuracy: 0.1519, Validation Loss: 1.9812, Validation Accuracy: 0.0060
# Epoch 9/40, Training Loss: 1.9459, Training Accuracy: 0.1533, Validation Loss: 1.9872, Validation Accuracy: 0.0980
# => Saving checkpoint
# Epoch 10/40, Training Loss: 1.9457, Training Accuracy: 0.1590, Validation Loss: 2.1946, Validation Accuracy: 0.0060
# Epoch 11/40, Training Loss: 1.9469, Training Accuracy: 0.1623, Validation Loss: 1.9336, Validation Accuracy: 0.0980
# Epoch 12/40, Training Loss: 1.9444, Training Accuracy: 0.1586, Validation Loss: 2.0256, Validation Accuracy: 0.0980
# => Saving checkpoint
# Epoch 13/40, Training Loss: 1.9500, Training Accuracy: 0.1550, Validation Loss: 2.0753, Validation Accuracy: 0.0060
# Epoch 14/40, Training Loss: 1.9456, Training Accuracy: 0.1597, Validation Loss: 1.7949, Validation Accuracy: 0.7180
# Epoch 15/40, Training Loss: 1.9475, Training Accuracy: 0.1583, Validation Loss: 2.0225, Validation Accuracy: 0.0980
# => Saving checkpoint
# Epoch 16/40, Training Loss: 1.9463, Training Accuracy: 0.1538, Validation Loss: 1.9030, Validation Accuracy: 0.7180
# Epoch 17/40, Training Loss: 1.9476, Training Accuracy: 0.1519, Validation Loss: 2.0498, Validation Accuracy: 0.0380
# Epoch 18/40, Training Loss: 1.9435, Training Accuracy: 0.1747, Validation Loss: 1.9841, Validation Accuracy: 0.0980
# => Saving checkpoint
# Epoch 19/40, Training Loss: 1.9479, Training Accuracy: 0.1581, Validation Loss: 2.0840, Validation Accuracy: 0.0100
# Epoch 20/40, Training Loss: 1.9490, Training Accuracy: 0.1583, Validation Loss: 1.8739, Validation Accuracy: 0.0980
# Epoch 21/40, Training Loss: 1.9455, Training Accuracy: 0.1566, Validation Loss: 1.9168, Validation Accuracy: 0.0980
# => Saving checkpoint
# Epoch 22/40, Training Loss: 1.9461, Training Accuracy: 0.1584, Validation Loss: 1.9803, Validation Accuracy: 0.0100
# Epoch 23/40, Training Loss: 1.9443, Training Accuracy: 0.1569, Validation Loss: 1.9503, Validation Accuracy: 0.0980
# Epoch 24/40, Training Loss: 1.9463, Training Accuracy: 0.1587, Validation Loss: 1.9973, Validation Accuracy: 0.0980
# => Saving checkpoint
# Epoch 25/40, Training Loss: 1.9415, Training Accuracy: 0.1726, Validation Loss: 1.9553, Validation Accuracy: 0.0980
# Epoch 26/40, Training Loss: 1.9432, Training Accuracy: 0.1618, Validation Loss: 1.9109, Validation Accuracy: 0.0980
# Epoch 27/40, Training Loss: 1.9454, Training Accuracy: 0.1569, Validation Loss: 1.9566, Validation Accuracy: 0.0060
# => Saving checkpoint
# Epoch 28/40, Training Loss: 1.9446, Training Accuracy: 0.1609, Validation Loss: 1.9045, Validation Accuracy: 0.0980
# Epoch 29/40, Training Loss: 1.9454, Training Accuracy: 0.1561, Validation Loss: 2.0369, Validation Accuracy: 0.0980
# Epoch 30/40, Training Loss: 1.9485, Training Accuracy: 0.1513, Validation Loss: 1.9378, Validation Accuracy: 0.0060
# => Saving checkpoint
# Epoch 31/40, Training Loss: 1.9430, Training Accuracy: 0.1603, Validation Loss: 1.9455, Validation Accuracy: 0.0060
# Epoch 32/40, Training Loss: 1.9456, Training Accuracy: 0.1612, Validation Loss: 1.9565, Validation Accuracy: 0.0980
# Epoch 33/40, Training Loss: 1.9465, Training Accuracy: 0.1586, Validation Loss: 2.0013, Validation Accuracy: 0.0060
# => Saving checkpoint
# Epoch 34/40, Training Loss: 1.9444, Training Accuracy: 0.1590, Validation Loss: 1.9764, Validation Accuracy: 0.0980
# Epoch 35/40, Training Loss: 1.9440, Training Accuracy: 0.1609, Validation Loss: 1.9613, Validation Accuracy: 0.0380
# Epoch 36/40, Training Loss: 1.9434, Training Accuracy: 0.1603, Validation Loss: 1.9231, Validation Accuracy: 0.0980
# => Saving checkpoint
# Epoch 37/40, Training Loss: 1.9432, Training Accuracy: 0.1679, Validation Loss: 1.9857, Validation Accuracy: 0.0980
# Epoch 38/40, Training Loss: 1.9425, Training Accuracy: 0.1703, Validation Loss: 2.0185, Validation Accuracy: 0.0980
# Epoch 39/40, Training Loss: 1.9457, Training Accuracy: 0.1578, Validation Loss: 1.8329, Validation Accuracy: 0.0980
# => Saving checkpoint
# Epoch 40/40, Training Loss: 1.9462, Training Accuracy: 0.1547, Validation Loss: 1.9436, Validation Accuracy: 0.0060

# %% [markdown]
# # Results

# %%
model.eval()

test_preds = []
test_labels = []

with torch.no_grad():
    
    test_acc = 0.0
    
    for data, labels in test_loader:
        
        data = data.to(device)
        labels = labels.to(device)
        
        data = data.reshape(data.shape[0], data.shape[1]*data.shape[2], data.shape[3])
        
        outputs = model(data)
        
        _, preds = torch.max(outputs, 1)
        
        test_preds.extend(preds.cpu().numpy())
        test_labels.extend(labels.cpu().numpy())
        
        test_acc += get_accuracy(outputs, labels) * data.size(0)
    
    test_acc = test_acc / len(test_data)
    
    print(f"Test Accuracy: {test_acc:.4f}")
# Out:
# Test Accuracy: 0.0040

# %%
report = classification_report(test_labels, test_preds, target_names=target_labels)

print(report)
# Out:
#                                 precision    recall  f1-score   support
#
#               Melanocytic nevi       0.00      0.00      0.00       341
#                       Melanoma       0.00      0.00      0.00        43
# Benign keratosis like lesions        0.00      0.00      0.00        57
#           Basal cell carcinoma       0.00      0.00      0.00        25
#              Actinic keratoses       0.00      0.00      0.00        18
#               Vascular lesions       0.00      0.00      0.00        14
#                 Dermatofibroma       0.00      1.00      0.01         2
#
#                       accuracy                           0.00       500
#                      macro avg       0.00      0.14      0.00       500
#                   weighted avg       0.00      0.00      0.00       500
# /opt/conda/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /opt/conda/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /opt/conda/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
confusion_mtx = confusion_matrix(test_labels, test_preds)

plot_confusion_matrix(confusion_mtx, target_labels)
